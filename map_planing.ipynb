# %% [markdown]
# ## map visualize

# %% [markdown]
# ### map review

# %%
# if wana get information form map
import carla
client = carla.Client('localhost', 2000)
client.set_timeout(10.0)
world = client.get_world()
carla_map = world.get_map()

# Get all waypoints
waypoints = carla_map.generate_waypoints(2.0)

# %%
from environment.tools.scene_designer import LocateObject
vmap = LocateObject(map_path="figure/map.png")

# %%
vmap.show_map_with_click()
# Out:
# Clicked at pixel: (4569, 825), meters: (-266.98, -369.93)

# %%
vmap.get_click_history()
# Out:
# {(0, 0, 255): [(7.1, -90.39), (7.1, -65.26), (-23.15, -7.21)],
#  (0, 255, 0): [(3.14, -71.89),
#   (4.07, -47.7),
#   (4.07, -47.7),
#   (2.33, -14.54),
#   (-17.8, -9.42),
#   (-45.25, -23.62),
#   (-75.03, -32.11),
#   (-114.12, -26.29),
#   (-161.35, -15.01),
#   (-222.07, -3.84),
#   (-254.65, 1.51),
#   (-286.75, 0.12),
#   (-331.66, -25.83),
#   (-350.04, -53.05),
#   (-353.64, -101.09),
#   (-350.15, -129.82),
#   (-348.06, -176.94),
#   (-348.18, -212.65),
#   (-348.29, -249.99),
#   (-347.83, -284.89),
#   (-347.25, -321.89),
#   (-346.2, -354.92),
#   (-359.34, -364.11),
#   (-331.66, -365.98),
#   (-298.85, -365.86),
#   (-256.74, -365.74),
#   (-220.45, -365.04)],
#  (255, 0, 0): [(-243.94, -369.58)],
#  (255, 255, 0): [(-333.05, -369.0)],
#  (0, 255, 255): [],
#  (255, 0, 255): []}

# %%
vmap.place_on_map(["box",(2.91, -98.42),0,"red"])
vmap.place_on_map(["box",(-86.78, -369.12),0,"green"])

# %%
vmap.plot()
vmap.clear_object()
